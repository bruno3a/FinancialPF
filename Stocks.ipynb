# %%
#pip install yfinance

# %%
import yfinance as yf #https://pypi.org/project/yfinance/
import pandas as pd
import numpy as np
import requests
import re
import seaborn as sns
from matplotlib import pyplot as plt

# %%
pd.options.display.float_format = '{:.5f}'.format

# %%
MELI = yf.Ticker("MELI")

# %%
shares = ['SOXX', 'FIVG', 'LIT', 'TSLA', 'MELI', 'AAPL', 'AMZN', 'X', 'QCOM', 'NVDA']

# %%
for x,y in zip(shares, shares):
    globals()[x] = yf.Ticker(y)

# %%
for x,y in zip(shares, shares):
    globals()[x] = yf.Ticker(y).history(start="2018-01-01").iloc[:,[0,3,4]]

# %%
FIVG.sample(5)
# Out:
#                Open    Close  Volume
# Date
# 2020-03-06 23.52695 23.67406  177800
# 2019-09-30 24.00939 23.94090   35700
# 2020-04-30 24.90964 24.64412  147800
# 2020-10-12 30.10245 30.05295  288700
# 2019-08-08 23.49026 23.82194   90100

# %%
for i in [shares][0]:
    globals()[i] = pd.DataFrame(globals()[i], columns=['Date', 'Open', 'Close', 'Volume'])
    globals()[i].Date = globals()[i].index
    globals()[i].reset_index(drop=True, inplace=True)

# %%
FIVG
# Out:
#           Date     Open    Close  Volume
# 0   2019-03-05 24.34518 24.06495   12000
# 1   2019-03-06 24.18949 23.89175   26300
# 2   2019-03-07 23.91705 23.55703   35000
# 3   2019-03-08 23.44026 23.55021   42200
# 4   2019-03-11 23.74190 23.98905   57800
# ..         ...      ...      ...     ...
# 682 2021-11-15 40.84000 40.62000   58200
# 683 2021-11-16 40.55000 41.20000  334800
# 684 2021-11-17 41.15000 41.14000  144900
# 685 2021-11-18 41.41000 41.33000   81100
# 686 2021-11-19 41.32000 41.14000   90800
#
# [687 rows x 4 columns]

# %%
for i in [shares][0]:
    with plt.style.context('bmh'):
        plt.figure(figsize=(20,8))
        plt.title(i)
        sns.lineplot(x = globals()[i].Date, y = globals()[i].Close);

# %%
path = 'H:\My Drive\Formacion\Data Science\Financial\FinancialPF\CSVs\\'
for i in [shares][0]:
    (globals()[i]).to_csv(path + i + '.csv', index = False)
